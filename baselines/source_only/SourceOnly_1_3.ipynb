# %%
# ============================================================
# SOURCE ONLY BASELINE — ResNet50 (Training)
# Train only on source data, predict on target data.
# No domain adaptation. Used to judge how much DA methods help.
# ============================================================

import sys
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.utils import to_categorical
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt

sys.path.append(r"D:\Woodchip_moisture_content\Dataset")
from dataset_1_3 import SourceDataset, WoodChipTargetEvalDataset

# ============================================================
# 1. Settings
# ============================================================
SEED        = 42
NUM_CLASSES = 3
IMG_HEIGHT  = 224
IMG_WIDTH   = 224
CHANNELS    = 3
SAVE_DIR    = r"D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3"
os.makedirs(SAVE_DIR, exist_ok=True)

np.random.seed(SEED)
tf.random.set_seed(SEED)

# ============================================================
# 2. Load Data
# ============================================================
def dataset_to_numpy(dataset_1_3, has_labels=True):
    loader = DataLoader(dataset_1_3, batch_size=32, shuffle=False, num_workers=0)
    X_list, y_list = [], []
    for batch in loader:
        if has_labels:
            imgs, labels = batch
            y_list.append(labels.numpy())
        else:
            imgs = batch
        X_list.append(imgs.permute(0, 2, 3, 1).numpy())
    X = np.concatenate(X_list, axis=0).astype(np.float32)
    if has_labels:
        return X, np.concatenate(y_list, axis=0)
    return X

print("Loading data...")
Xs, ys_int      = dataset_to_numpy(SourceDataset())
Xt_eval, yt_int = dataset_to_numpy(WoodChipTargetEvalDataset())
print(f"Source: {Xs.shape} | Target: {Xt_eval.shape}")

# ============================================================
# 3. Train / Validation Split (source only)
# No target data used during training at all.
# ============================================================
ys = to_categorical(ys_int, num_classes=NUM_CLASSES)

Xs_train, Xs_val, ys_train, ys_val, ys_train_int, ys_val_int = train_test_split(
    Xs, ys, ys_int, test_size=0.2, random_state=SEED, stratify=ys_int
)

_, Xt_test, _, yt_test_int = train_test_split(
    Xt_eval, yt_int, test_size=0.2, random_state=SEED, stratify=yt_int
)

print(f"Xs_train: {Xs_train.shape} | Xs_val: {Xs_val.shape}")
print(f"Xt_test:  {Xt_test.shape}  (evaluation only)")

# ============================================================
# 4. Build ResNet50 Model
# ============================================================
def build_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, CHANNELS), num_classes=NUM_CLASSES):
    base = tf.keras.applications.ResNet50(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )
    base.trainable = True

    inputs = layers.Input(shape=input_shape)
    x = base(inputs, training=True)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return Model(inputs, outputs, name="resnet50_source_only")

model = build_model()
model.summary()

# ============================================================
# 5. Compile
# ============================================================
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ============================================================
# 6. Train on Source Only
# ============================================================
print("\nTraining Source Only model (ResNet50)...")
history = model.fit(
    Xs_train, ys_train,
    validation_data=(Xs_val, ys_val),
    epochs=100,
    batch_size=16,
    verbose=1
)
print("\nTraining complete!")

# ============================================================
# 7. Predictions
# ============================================================
val_preds     = np.argmax(model.predict(Xs_val), axis=1)
tgt_preds     = np.argmax(model.predict(Xt_test), axis=1)
src_probs_vis = model.predict(Xs)
src_preds_vis = np.argmax(src_probs_vis, axis=1)
tgt_probs_vis = model.predict(Xt_eval)
tgt_preds_vis = np.argmax(tgt_probs_vis, axis=1)

# ============================================================
# 8. Classification Reports
# ============================================================
print("\nClassification Report (Source Validation):")
print(classification_report(ys_val_int, val_preds, target_names=['Dry', 'Medium', 'Wet']))

print("Classification Report (Target Test):")
print(classification_report(yt_test_int, tgt_preds, target_names=['Dry', 'Medium', 'Wet']))

# ============================================================
# 9. Metrics Summary
# ============================================================
src_acc       = accuracy_score(ys_val_int, val_preds)
src_precision = precision_score(ys_val_int, val_preds, average='weighted')
src_recall    = recall_score(ys_val_int, val_preds, average='weighted')
src_f1        = f1_score(ys_val_int, val_preds, average='weighted')

tgt_acc       = accuracy_score(yt_test_int, tgt_preds)
tgt_precision = precision_score(yt_test_int, tgt_preds, average='weighted')
tgt_recall    = recall_score(yt_test_int, tgt_preds, average='weighted')
tgt_f1        = f1_score(yt_test_int, tgt_preds, average='weighted')

print("\nMETRICS SUMMARY")
print("=" * 50)
print(f"{'Metric':<16} {'Source':>10} {'Target':>10}")
print("-" * 50)
print(f"{'Accuracy':<16} {src_acc:>10.3f} {tgt_acc:>10.3f}")
print(f"{'Precision':<16} {src_precision:>10.3f} {tgt_precision:>10.3f}")
print(f"{'Recall':<16} {src_recall:>10.3f} {tgt_recall:>10.3f}")
print(f"{'F1':<16} {src_f1:>10.3f} {tgt_f1:>10.3f}")
print("=" * 50)

# ============================================================
# 10. Save Outputs
# ============================================================
np.save(os.path.join(SAVE_DIR, "Xs.npy"),            Xs)
np.save(os.path.join(SAVE_DIR, "ys_int.npy"),        ys_int)
np.save(os.path.join(SAVE_DIR, "Xt_eval.npy"),       Xt_eval)
np.save(os.path.join(SAVE_DIR, "yt_int.npy"),        yt_int)
np.save(os.path.join(SAVE_DIR, "ys_val_int.npy"),    ys_val_int)
np.save(os.path.join(SAVE_DIR, "val_preds.npy"),     val_preds)
np.save(os.path.join(SAVE_DIR, "yt_test_int.npy"),   yt_test_int)
np.save(os.path.join(SAVE_DIR, "tgt_preds.npy"),     tgt_preds)
np.save(os.path.join(SAVE_DIR, "src_probs_vis.npy"), src_probs_vis)
np.save(os.path.join(SAVE_DIR, "src_preds_vis.npy"), src_preds_vis)
np.save(os.path.join(SAVE_DIR, "tgt_probs_vis.npy"), tgt_probs_vis)
np.save(os.path.join(SAVE_DIR, "tgt_preds_vis.npy"), tgt_preds_vis)
print(f"\nAll outputs saved to: {SAVE_DIR}")
# Out:
# Loading data...
# Source: (800, 224, 224, 3) | Target: (400, 224, 224, 3)
# Xs_train: (640, 224, 224, 3) | Xs_val: (160, 224, 224, 3)
# Xt_test:  (80, 224, 224, 3)  (evaluation only)
# Model: "resnet50_source_only"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,145,539 (92.11 MB)
#  Trainable params: 24,092,419 (91.91 MB)
#  Non-trainable params: 53,120 (207.50 KB)
# Training Source Only model (ResNet50)...
# Epoch 1/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 51s 828ms/step - accuracy: 0.6719 - loss: 0.6923 - val_accuracy: 0.3000 - val_loss: 2.5711
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 796ms/step - accuracy: 0.9453 - loss: 0.1729 - val_accuracy: 0.3000 - val_loss: 3.4518
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 806ms/step - accuracy: 0.9891 - loss: 0.0556 - val_accuracy: 0.3000 - val_loss: 4.9872
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 0.9937 - loss: 0.0270 - val_accuracy: 0.3000 - val_loss: 9.8571
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 815ms/step - accuracy: 0.9922 - loss: 0.0213 - val_accuracy: 0.3000 - val_loss: 8.0077
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 808ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.3000 - val_loss: 14.2349
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 818ms/step - accuracy: 0.9984 - loss: 0.0073 - val_accuracy: 0.3000 - val_loss: 13.8961
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 850ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.3000 - val_loss: 17.6973
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 835ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.3000 - val_loss: 18.4884
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3000 - val_loss: 19.7268
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 831ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.3000 - val_loss: 19.7590
# Epoch 12/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 826ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.3000 - val_loss: 19.8624
# Epoch 13/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 813ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3000 - val_loss: 20.3743
# Epoch 14/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 813ms/step - accuracy: 1.0000 - loss: 7.9413e-04 - val_accuracy: 0.3000 - val_loss: 20.4653
# Epoch 15/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 810ms/step - accuracy: 1.0000 - loss: 6.1922e-04 - val_accuracy: 0.3000 - val_loss: 19.7731
# Epoch 16/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 828ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.3000 - val_loss: 20.5962
# Epoch 17/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 3.4019e-04 - val_accuracy: 0.3000 - val_loss: 21.0015
# Epoch 18/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 830ms/step - accuracy: 1.0000 - loss: 5.1304e-04 - val_accuracy: 0.3000 - val_loss: 18.3066
# Epoch 19/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 811ms/step - accuracy: 1.0000 - loss: 5.6248e-04 - val_accuracy: 0.3000 - val_loss: 14.4885
# Epoch 20/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 4.9098e-04 - val_accuracy: 0.3000 - val_loss: 10.0577
# Epoch 21/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 3.0476e-04 - val_accuracy: 0.3000 - val_loss: 6.1345
# Epoch 22/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 810ms/step - accuracy: 1.0000 - loss: 2.0410e-04 - val_accuracy: 0.2438 - val_loss: 3.0179
# Epoch 23/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 826ms/step - accuracy: 1.0000 - loss: 2.7599e-04 - val_accuracy: 0.3688 - val_loss: 1.9066
# Epoch 24/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 807ms/step - accuracy: 1.0000 - loss: 2.5787e-04 - val_accuracy: 0.4437 - val_loss: 2.7340
# Epoch 25/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 823ms/step - accuracy: 1.0000 - loss: 2.8673e-04 - val_accuracy: 0.4375 - val_loss: 3.7960
# Epoch 26/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 824ms/step - accuracy: 1.0000 - loss: 2.1621e-04 - val_accuracy: 0.4250 - val_loss: 4.5696
# Epoch 27/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 824ms/step - accuracy: 1.0000 - loss: 2.6225e-04 - val_accuracy: 0.4250 - val_loss: 5.1347
# Epoch 28/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 820ms/step - accuracy: 1.0000 - loss: 2.5805e-04 - val_accuracy: 0.4313 - val_loss: 5.5288
# Epoch 29/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 826ms/step - accuracy: 1.0000 - loss: 2.2089e-04 - val_accuracy: 0.4313 - val_loss: 5.7483
# Epoch 30/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 831ms/step - accuracy: 1.0000 - loss: 3.1111e-04 - val_accuracy: 0.4313 - val_loss: 5.2552
# Epoch 31/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 816ms/step - accuracy: 1.0000 - loss: 1.8369e-04 - val_accuracy: 0.4938 - val_loss: 4.3686
# Epoch 32/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 1.5693e-04 - val_accuracy: 0.5750 - val_loss: 3.2253
# Epoch 33/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 1.6886e-04 - val_accuracy: 0.6938 - val_loss: 1.9636
# Epoch 34/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 814ms/step - accuracy: 1.0000 - loss: 2.0239e-04 - val_accuracy: 0.7875 - val_loss: 1.4220
# Epoch 35/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 1.2838e-04 - val_accuracy: 0.8062 - val_loss: 1.0703
# Epoch 36/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 831ms/step - accuracy: 1.0000 - loss: 1.9922e-04 - val_accuracy: 0.8625 - val_loss: 0.7927
# Epoch 37/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 823ms/step - accuracy: 1.0000 - loss: 9.1536e-05 - val_accuracy: 0.8875 - val_loss: 0.7575
# Epoch 38/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 836ms/step - accuracy: 1.0000 - loss: 1.8371e-04 - val_accuracy: 0.8687 - val_loss: 0.7636
# Epoch 39/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 8.9901e-05 - val_accuracy: 0.8687 - val_loss: 0.7832
# Epoch 40/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 2.2074e-04 - val_accuracy: 0.8562 - val_loss: 0.8764
# Epoch 41/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 1.6123e-04 - val_accuracy: 0.8562 - val_loss: 0.8924
# Epoch 42/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 1.5552e-04 - val_accuracy: 0.8625 - val_loss: 0.8568
# Epoch 43/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 7.1816e-05 - val_accuracy: 0.8625 - val_loss: 0.8227
# Epoch 44/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 823ms/step - accuracy: 1.0000 - loss: 1.1753e-04 - val_accuracy: 0.8625 - val_loss: 0.7639
# Epoch 45/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 9.8076e-05 - val_accuracy: 0.8625 - val_loss: 0.7504
# Epoch 46/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 842ms/step - accuracy: 1.0000 - loss: 7.1124e-05 - val_accuracy: 0.8625 - val_loss: 0.7720
# Epoch 47/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 1.2085e-04 - val_accuracy: 0.8625 - val_loss: 0.7920
# Epoch 48/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 826ms/step - accuracy: 1.0000 - loss: 1.4899e-04 - val_accuracy: 0.8687 - val_loss: 0.7737
# Epoch 49/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 818ms/step - accuracy: 1.0000 - loss: 6.5585e-05 - val_accuracy: 0.8687 - val_loss: 0.7930
# Epoch 50/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 5.9583e-05 - val_accuracy: 0.8687 - val_loss: 0.8102
# Epoch 51/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 820ms/step - accuracy: 1.0000 - loss: 8.0506e-05 - val_accuracy: 0.8687 - val_loss: 0.7818
# Epoch 52/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 6.2423e-05 - val_accuracy: 0.8687 - val_loss: 0.8305
# Epoch 53/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 812ms/step - accuracy: 1.0000 - loss: 4.7143e-05 - val_accuracy: 0.8687 - val_loss: 0.8285
# Epoch 54/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 818ms/step - accuracy: 1.0000 - loss: 2.9883e-04 - val_accuracy: 0.8687 - val_loss: 1.0336
# Epoch 55/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 834ms/step - accuracy: 1.0000 - loss: 4.9063e-05 - val_accuracy: 0.8750 - val_loss: 0.9863
# Epoch 56/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 820ms/step - accuracy: 1.0000 - loss: 6.5763e-05 - val_accuracy: 0.8687 - val_loss: 0.9050
# Epoch 57/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 825ms/step - accuracy: 1.0000 - loss: 4.0555e-04 - val_accuracy: 0.8562 - val_loss: 1.1155
# Epoch 58/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 819ms/step - accuracy: 0.9563 - loss: 0.2078 - val_accuracy: 0.5688 - val_loss: 1.4991
# Epoch 59/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 0.8234 - loss: 0.6092 - val_accuracy: 0.7375 - val_loss: 2.7616
# Epoch 60/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 812ms/step - accuracy: 0.9438 - loss: 0.2036 - val_accuracy: 0.6375 - val_loss: 5.0358
# Epoch 61/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 0.9875 - loss: 0.0699 - val_accuracy: 0.5250 - val_loss: 11.3571
# Epoch 62/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 828ms/step - accuracy: 0.9922 - loss: 0.0266 - val_accuracy: 0.6438 - val_loss: 2.3695
# Epoch 63/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 815ms/step - accuracy: 0.9891 - loss: 0.0299 - val_accuracy: 0.7063 - val_loss: 2.2904
# Epoch 64/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 836ms/step - accuracy: 0.9797 - loss: 0.0652 - val_accuracy: 0.6000 - val_loss: 2.2634
# Epoch 65/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 0.9781 - loss: 0.0714 - val_accuracy: 0.7500 - val_loss: 1.4295
# Epoch 66/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 849ms/step - accuracy: 0.9922 - loss: 0.0298 - val_accuracy: 0.8875 - val_loss: 0.4994
# Epoch 67/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 824ms/step - accuracy: 0.9984 - loss: 0.0071 - val_accuracy: 0.8813 - val_loss: 0.4884
# Epoch 68/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 830ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9000 - val_loss: 0.4360
# Epoch 69/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 819ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9000 - val_loss: 0.4112
# Epoch 70/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 819ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9125 - val_loss: 0.4249
# Epoch 71/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 824ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9187 - val_loss: 0.4227
# Epoch 72/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 825ms/step - accuracy: 1.0000 - loss: 6.9015e-04 - val_accuracy: 0.9187 - val_loss: 0.4118
# Epoch 73/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 828ms/step - accuracy: 1.0000 - loss: 4.8679e-04 - val_accuracy: 0.9187 - val_loss: 0.4293
# Epoch 74/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 823ms/step - accuracy: 1.0000 - loss: 5.5713e-04 - val_accuracy: 0.9187 - val_loss: 0.4211
# Epoch 75/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 3.4253e-04 - val_accuracy: 0.9187 - val_loss: 0.4235
# Epoch 76/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 819ms/step - accuracy: 1.0000 - loss: 4.7589e-04 - val_accuracy: 0.9250 - val_loss: 0.4193
# Epoch 77/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 4.2161e-04 - val_accuracy: 0.9250 - val_loss: 0.4255
# Epoch 78/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 2.3855e-04 - val_accuracy: 0.9250 - val_loss: 0.4306
# Epoch 79/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 2.3518e-04 - val_accuracy: 0.9250 - val_loss: 0.4355
# Epoch 80/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 2.0345e-04 - val_accuracy: 0.9250 - val_loss: 0.4442
# Epoch 81/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 849ms/step - accuracy: 1.0000 - loss: 2.8193e-04 - val_accuracy: 0.9250 - val_loss: 0.4479
# Epoch 82/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 859ms/step - accuracy: 1.0000 - loss: 8.4010e-05 - val_accuracy: 0.9250 - val_loss: 0.4520
# Epoch 83/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 838ms/step - accuracy: 1.0000 - loss: 1.4804e-04 - val_accuracy: 0.9187 - val_loss: 0.4592
# Epoch 84/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 840ms/step - accuracy: 1.0000 - loss: 1.6951e-04 - val_accuracy: 0.9250 - val_loss: 0.4629
# Epoch 85/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 1.9849e-04 - val_accuracy: 0.9250 - val_loss: 0.4670
# Epoch 86/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 820ms/step - accuracy: 1.0000 - loss: 1.2785e-04 - val_accuracy: 0.9187 - val_loss: 0.4757
# Epoch 87/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 1.3700e-04 - val_accuracy: 0.9250 - val_loss: 0.4745
# Epoch 88/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 820ms/step - accuracy: 1.0000 - loss: 1.3299e-04 - val_accuracy: 0.9250 - val_loss: 0.4746
# Epoch 89/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 823ms/step - accuracy: 1.0000 - loss: 8.6562e-05 - val_accuracy: 0.9250 - val_loss: 0.4758
# Epoch 90/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 1.3825e-04 - val_accuracy: 0.9250 - val_loss: 0.4780
# Epoch 91/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 831ms/step - accuracy: 1.0000 - loss: 1.2396e-04 - val_accuracy: 0.9250 - val_loss: 0.4839
# Epoch 92/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 826ms/step - accuracy: 1.0000 - loss: 1.7033e-04 - val_accuracy: 0.9187 - val_loss: 0.4991
# Epoch 93/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 826ms/step - accuracy: 1.0000 - loss: 1.0110e-04 - val_accuracy: 0.9250 - val_loss: 0.4985
# Epoch 94/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 1.9162e-04 - val_accuracy: 0.9250 - val_loss: 0.4994
# Epoch 95/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 9.3308e-05 - val_accuracy: 0.9250 - val_loss: 0.5057
# Epoch 96/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 6.7153e-05 - val_accuracy: 0.9250 - val_loss: 0.5055
# Epoch 97/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 1.1164e-04 - val_accuracy: 0.9250 - val_loss: 0.5041
# Epoch 98/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 838ms/step - accuracy: 1.0000 - loss: 7.1320e-05 - val_accuracy: 0.9250 - val_loss: 0.5053
# Epoch 99/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 831ms/step - accuracy: 1.0000 - loss: 6.6105e-05 - val_accuracy: 0.9250 - val_loss: 0.5055
# Epoch 100/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 842ms/step - accuracy: 1.0000 - loss: 1.8105e-04 - val_accuracy: 0.9312 - val_loss: 0.5042
#
# Training complete!
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 320ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 701ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 336ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 326ms/step
#
# Classification Report (Source Validation):
#               precision    recall  f1-score   support
#
#          Dry       0.92      0.92      0.92        48
#       Medium       0.92      0.91      0.91        64
#          Wet       0.96      0.98      0.97        48
#
#     accuracy                           0.93       160
#    macro avg       0.93      0.93      0.93       160
# weighted avg       0.93      0.93      0.93       160
#
# Classification Report (Target Test):
#               precision    recall  f1-score   support
#
#          Dry       1.00      0.17      0.29        24
#       Medium       0.31      0.12      0.18        32
#          Wet       0.38      1.00      0.55        24
#
#     accuracy                           0.40        80
#    macro avg       0.56      0.43      0.34        80
# weighted avg       0.54      0.40      0.32        80
#
#
# METRICS SUMMARY
# ==================================================
# Metric               Source     Target
# --------------------------------------------------
# Accuracy              0.931      0.400
# Precision             0.931      0.537
# Recall                0.931      0.400
# F1                    0.931      0.322
# ==================================================
#
# All outputs saved to: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3

# %%
# ============================================================
# SOURCE ONLY BASELINE — ResNet50 (Visualization)
# Load saved outputs and generate confusion matrix,
# prediction grids, and copy original images.
# ============================================================

import os
import sys
import shutil
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

sys.path.append(r"D:\Woodchip_moisture_content\Dataset")
from dataset_1_3 import SourceDataset, WoodChipTargetEvalDataset

SAVE_DIR    = r"D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3"
LABEL_NAMES = ['Dry', 'Medium', 'Wet']

# ============================================================
# Load Saved Outputs
# ============================================================
Xs            = np.load(os.path.join(SAVE_DIR, "Xs.npy"))
ys_int        = np.load(os.path.join(SAVE_DIR, "ys_int.npy"))
Xt_eval       = np.load(os.path.join(SAVE_DIR, "Xt_eval.npy"))
yt_int        = np.load(os.path.join(SAVE_DIR, "yt_int.npy"))
ys_val_int    = np.load(os.path.join(SAVE_DIR, "ys_val_int.npy"))
val_preds     = np.load(os.path.join(SAVE_DIR, "val_preds.npy"))
src_probs_vis = np.load(os.path.join(SAVE_DIR, "src_probs_vis.npy"))
src_preds_vis = np.load(os.path.join(SAVE_DIR, "src_preds_vis.npy"))
tgt_probs_vis = np.load(os.path.join(SAVE_DIR, "tgt_probs_vis.npy"))
tgt_preds_vis = np.load(os.path.join(SAVE_DIR, "tgt_preds_vis.npy"))

print("Outputs loaded successfully.")

# ============================================================
# Load Original File Paths
# ============================================================
src_dataset = SourceDataset()
tgt_dataset = WoodChipTargetEvalDataset()

src_paths = [s[0] for s in src_dataset.samples]
tgt_paths = [s[0] for s in tgt_dataset.samples]

# ============================================================
# Confusion Matrix
# ============================================================
def plot_confusion_matrix(y_true, y_pred, title, filename):
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(6, 5), dpi=300)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=LABEL_NAMES, yticklabels=LABEL_NAMES,
                linewidths=0.5, ax=ax)
    ax.set_xlabel('Predicted Label', fontsize=12)
    ax.set_ylabel('True Label', fontsize=12)
    ax.set_title(title, fontsize=14, fontweight='bold')
    plt.tight_layout()
    save_path = os.path.join(SAVE_DIR, filename)
    plt.savefig(save_path, format='jpg', dpi=300, bbox_inches='tight')
    plt.show()
    print(f"Saved: {save_path}")

plot_confusion_matrix(yt_int, tgt_preds_vis,
                      'Confusion Matrix — Target Domain (Full)',
                      'confusion_matrix_target_full.jpg')

# ============================================================
# Visualization Grid
# ============================================================
np.random.seed(42)
src_indices = np.random.choice(len(Xs), 5, replace=False)
tgt_indices = np.random.choice(len(Xt_eval), 5, replace=False)

def save_visualization_grid(X, y_true, y_pred, y_probs, indices, title, filename):
    fig, axes = plt.subplots(1, 5, figsize=(15, 3), dpi=300)
    for ax, idx in zip(axes, indices):
        img = X[idx].copy()
        img = (img - img.min()) / (img.max() - img.min())
        ax.imshow(img)
        ax.axis('off')
        pred  = y_pred[idx]
        true  = y_true[idx]
        conf  = y_probs[idx][pred]
        color = 'green' if pred == true else 'red'
        ax.set_title(
            f"True: {LABEL_NAMES[true]}\nPred: {LABEL_NAMES[pred]}\nConf: {conf:.2f}",
            color=color, fontsize=10, fontweight='bold'
        )
    plt.suptitle(title, fontsize=14, fontweight='bold', y=1.05)
    plt.tight_layout()
    save_path = os.path.join(SAVE_DIR, filename)
    plt.savefig(save_path, format='jpg', dpi=300, bbox_inches='tight')
    plt.show()
    print(f"Saved: {save_path}")

print("\nVisualizing predictions on SOURCE domain samples:")
save_visualization_grid(Xs, ys_int, src_preds_vis, src_probs_vis, src_indices,
                        'ResNet50 Source Only Predictions (Source Domain)',
                        'source_predictions_grid.jpg')

print("\nVisualizing predictions on TARGET domain samples:")
save_visualization_grid(Xt_eval, yt_int, tgt_preds_vis, tgt_probs_vis, tgt_indices,
                        'ResNet50 Source Only Predictions (Target Domain)',
                        'target_predictions_grid.jpg')

# ============================================================
# Copy Original Images
# ============================================================
src_folder = os.path.join(SAVE_DIR, "source_samples")
tgt_folder = os.path.join(SAVE_DIR, "target_samples")
os.makedirs(src_folder, exist_ok=True)
os.makedirs(tgt_folder, exist_ok=True)

def copy_original_images(paths, y_true, y_pred, y_probs, indices, folder):
    for i, idx in enumerate(indices):
        true_label = LABEL_NAMES[y_true[idx]]
        pred_label = LABEL_NAMES[y_pred[idx]]
        conf       = y_probs[idx][y_pred[idx]]
        ext        = os.path.splitext(paths[idx])[1]
        filename   = f"{i+1}_True_{true_label}_Pred_{pred_label}_Conf_{conf:.2f}{ext}"
        save_path  = os.path.join(folder, filename)
        shutil.copy2(paths[idx], save_path)
        print(f"Saved: {save_path}")

print("\nCopying original source domain images...")
copy_original_images(src_paths, ys_int, src_preds_vis, src_probs_vis, src_indices, src_folder)

print("\nCopying original target domain images...")
copy_original_images(tgt_paths, yt_int, tgt_preds_vis, tgt_probs_vis, tgt_indices, tgt_folder)

print("\nDone! Check folders:")
print(f"  Source: {src_folder}")
print(f"  Target: {tgt_folder}")

# ============================================================
# Prediction Summary
# ============================================================
print("\n" + "="*60)
print("PREDICTION SUMMARY")
print("="*60)
src_n_correct = int(np.sum(src_preds_vis == ys_int))
tgt_n_correct = int(np.sum(tgt_preds_vis == yt_int))
print(f"Source Domain: {src_n_correct}/{len(ys_int)} correct ({accuracy_score(ys_int, src_preds_vis):.1%})")
print(f"Target Domain: {tgt_n_correct}/{len(yt_int)} correct ({accuracy_score(yt_int, tgt_preds_vis):.1%})")
print("="*60)
# Out:
# Outputs loaded successfully.
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\confusion_matrix_target_full.jpg
#
# Visualizing predictions on SOURCE domain samples:
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\source_predictions_grid.jpg
#
# Visualizing predictions on TARGET domain samples:
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\target_predictions_grid.jpg
#
# Copying original source domain images...
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\source_samples\1_True_Wet_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\source_samples\2_True_Wet_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\source_samples\3_True_Dry_Pred_Dry_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\source_samples\4_True_Medium_Pred_Medium_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\source_samples\5_True_Dry_Pred_Dry_Conf_1.00.jpg
#
# Copying original target domain images...
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\target_samples\1_True_Medium_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\target_samples\2_True_Medium_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\target_samples\3_True_Dry_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\target_samples\4_True_Dry_Pred_Medium_Conf_0.47.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\target_samples\5_True_Medium_Pred_Wet_Conf_0.89.jpg
#
# Done! Check folders:
#   Source: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\source_samples
#   Target: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_3\target_samples
#
# ============================================================
# PREDICTION SUMMARY
# ============================================================
# Source Domain: 789/800 correct (98.6%)
# Target Domain: 168/400 correct (42.0%)
# ============================================================
