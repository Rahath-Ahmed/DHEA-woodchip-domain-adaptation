# %%
# ============================================================
# SOURCE ONLY BASELINE — ResNet50 (Training)
# Train only on source data, predict on target data.
# No domain adaptation. Used to judge how much DA methods help.
# ============================================================

import sys
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.utils import to_categorical
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt

sys.path.append(r"D:\Woodchip_moisture_content\Dataset")
from dataset_2_3 import SourceDataset, WoodChipTargetEvalDataset

# ============================================================
# 1. Settings
# ============================================================
SEED        = 42
NUM_CLASSES = 3
IMG_HEIGHT  = 224
IMG_WIDTH   = 224
CHANNELS    = 3
SAVE_DIR    = r"D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3"
os.makedirs(SAVE_DIR, exist_ok=True)

np.random.seed(SEED)
tf.random.set_seed(SEED)

# ============================================================
# 2. Load Data
# ============================================================
def dataset_to_numpy(dataset_2_3, has_labels=True):
    loader = DataLoader(dataset_2_3, batch_size=32, shuffle=False, num_workers=0)
    X_list, y_list = [], []
    for batch in loader:
        if has_labels:
            imgs, labels = batch
            y_list.append(labels.numpy())
        else:
            imgs = batch
        X_list.append(imgs.permute(0, 2, 3, 1).numpy())
    X = np.concatenate(X_list, axis=0).astype(np.float32)
    if has_labels:
        return X, np.concatenate(y_list, axis=0)
    return X

print("Loading data...")
Xs, ys_int      = dataset_to_numpy(SourceDataset())
Xt_eval, yt_int = dataset_to_numpy(WoodChipTargetEvalDataset())
print(f"Source: {Xs.shape} | Target: {Xt_eval.shape}")

# ============================================================
# 3. Train / Validation Split (source only)
# No target data used during training at all.
# ============================================================
ys = to_categorical(ys_int, num_classes=NUM_CLASSES)

Xs_train, Xs_val, ys_train, ys_val, ys_train_int, ys_val_int = train_test_split(
    Xs, ys, ys_int, test_size=0.2, random_state=SEED, stratify=ys_int
)

_, Xt_test, _, yt_test_int = train_test_split(
    Xt_eval, yt_int, test_size=0.2, random_state=SEED, stratify=yt_int
)

print(f"Xs_train: {Xs_train.shape} | Xs_val: {Xs_val.shape}")
print(f"Xt_test:  {Xt_test.shape}  (evaluation only)")

# ============================================================
# 4. Build ResNet50 Model
# ============================================================
def build_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, CHANNELS), num_classes=NUM_CLASSES):
    base = tf.keras.applications.ResNet50(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )
    base.trainable = True

    inputs = layers.Input(shape=input_shape)
    x = base(inputs, training=True)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return Model(inputs, outputs, name="resnet50_source_only")

model = build_model()
model.summary()

# ============================================================
# 5. Compile
# ============================================================
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ============================================================
# 6. Train on Source Only
# ============================================================
print("\nTraining Source Only model (ResNet50)...")
history = model.fit(
    Xs_train, ys_train,
    validation_data=(Xs_val, ys_val),
    epochs=100,
    batch_size=16,
    verbose=1
)
print("\nTraining complete!")

# ============================================================
# 7. Predictions
# ============================================================
val_preds     = np.argmax(model.predict(Xs_val), axis=1)
tgt_preds     = np.argmax(model.predict(Xt_test), axis=1)
src_probs_vis = model.predict(Xs)
src_preds_vis = np.argmax(src_probs_vis, axis=1)
tgt_probs_vis = model.predict(Xt_eval)
tgt_preds_vis = np.argmax(tgt_probs_vis, axis=1)

# ============================================================
# 8. Classification Reports
# ============================================================
print("\nClassification Report (Source Validation):")
print(classification_report(ys_val_int, val_preds, target_names=['Dry', 'Medium', 'Wet']))

print("Classification Report (Target Test):")
print(classification_report(yt_test_int, tgt_preds, target_names=['Dry', 'Medium', 'Wet']))

# ============================================================
# 9. Metrics Summary
# ============================================================
src_acc       = accuracy_score(ys_val_int, val_preds)
src_precision = precision_score(ys_val_int, val_preds, average='weighted')
src_recall    = recall_score(ys_val_int, val_preds, average='weighted')
src_f1        = f1_score(ys_val_int, val_preds, average='weighted')

tgt_acc       = accuracy_score(yt_test_int, tgt_preds)
tgt_precision = precision_score(yt_test_int, tgt_preds, average='weighted')
tgt_recall    = recall_score(yt_test_int, tgt_preds, average='weighted')
tgt_f1        = f1_score(yt_test_int, tgt_preds, average='weighted')

print("\nMETRICS SUMMARY")
print("=" * 50)
print(f"{'Metric':<16} {'Source':>10} {'Target':>10}")
print("-" * 50)
print(f"{'Accuracy':<16} {src_acc:>10.3f} {tgt_acc:>10.3f}")
print(f"{'Precision':<16} {src_precision:>10.3f} {tgt_precision:>10.3f}")
print(f"{'Recall':<16} {src_recall:>10.3f} {tgt_recall:>10.3f}")
print(f"{'F1':<16} {src_f1:>10.3f} {tgt_f1:>10.3f}")
print("=" * 50)

# ============================================================
# 10. Save Outputs
# ============================================================
np.save(os.path.join(SAVE_DIR, "Xs.npy"),            Xs)
np.save(os.path.join(SAVE_DIR, "ys_int.npy"),        ys_int)
np.save(os.path.join(SAVE_DIR, "Xt_eval.npy"),       Xt_eval)
np.save(os.path.join(SAVE_DIR, "yt_int.npy"),        yt_int)
np.save(os.path.join(SAVE_DIR, "ys_val_int.npy"),    ys_val_int)
np.save(os.path.join(SAVE_DIR, "val_preds.npy"),     val_preds)
np.save(os.path.join(SAVE_DIR, "yt_test_int.npy"),   yt_test_int)
np.save(os.path.join(SAVE_DIR, "tgt_preds.npy"),     tgt_preds)
np.save(os.path.join(SAVE_DIR, "src_probs_vis.npy"), src_probs_vis)
np.save(os.path.join(SAVE_DIR, "src_preds_vis.npy"), src_preds_vis)
np.save(os.path.join(SAVE_DIR, "tgt_probs_vis.npy"), tgt_probs_vis)
np.save(os.path.join(SAVE_DIR, "tgt_preds_vis.npy"), tgt_preds_vis)
print(f"\nAll outputs saved to: {SAVE_DIR}")
# Out:
# Loading data...
# Source: (800, 224, 224, 3) | Target: (400, 224, 224, 3)
# Xs_train: (640, 224, 224, 3) | Xs_val: (160, 224, 224, 3)
# Xt_test:  (80, 224, 224, 3)  (evaluation only)
# Model: "resnet50_source_only"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,145,539 (92.11 MB)
#  Trainable params: 24,092,419 (91.91 MB)
#  Non-trainable params: 53,120 (207.50 KB)
# Training Source Only model (ResNet50)...
# Epoch 1/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 50s 829ms/step - accuracy: 0.6313 - loss: 0.7781 - val_accuracy: 0.3000 - val_loss: 1.1590
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 833ms/step - accuracy: 0.9484 - loss: 0.1838 - val_accuracy: 0.4000 - val_loss: 1.2411
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 795ms/step - accuracy: 0.9844 - loss: 0.0633 - val_accuracy: 0.4000 - val_loss: 2.5564
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 823ms/step - accuracy: 0.9922 - loss: 0.0388 - val_accuracy: 0.4000 - val_loss: 5.2559
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 0.9969 - loss: 0.0184 - val_accuracy: 0.3000 - val_loss: 7.5233
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 0.9984 - loss: 0.0074 - val_accuracy: 0.4000 - val_loss: 10.2407
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 819ms/step - accuracy: 0.9984 - loss: 0.0062 - val_accuracy: 0.4000 - val_loss: 13.7248
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.4000 - val_loss: 15.0239
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 825ms/step - accuracy: 0.9984 - loss: 0.0046 - val_accuracy: 0.4000 - val_loss: 14.1016
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 826ms/step - accuracy: 0.9984 - loss: 0.0062 - val_accuracy: 0.4000 - val_loss: 15.1230
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 0.9984 - loss: 0.0066 - val_accuracy: 0.4000 - val_loss: 18.4591
# Epoch 12/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 828ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.4000 - val_loss: 18.9951
# Epoch 13/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4000 - val_loss: 18.1845
# Epoch 14/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 814ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4000 - val_loss: 16.5105
# Epoch 15/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 811ms/step - accuracy: 1.0000 - loss: 8.1258e-04 - val_accuracy: 0.4000 - val_loss: 14.6211
# Epoch 16/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 814ms/step - accuracy: 1.0000 - loss: 6.8066e-04 - val_accuracy: 0.4000 - val_loss: 12.4884
# Epoch 17/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 824ms/step - accuracy: 1.0000 - loss: 7.3860e-04 - val_accuracy: 0.4000 - val_loss: 10.1254
# Epoch 18/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 824ms/step - accuracy: 1.0000 - loss: 3.2470e-04 - val_accuracy: 0.4000 - val_loss: 7.4492
# Epoch 19/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 813ms/step - accuracy: 1.0000 - loss: 2.8038e-04 - val_accuracy: 0.4000 - val_loss: 4.7848
# Epoch 20/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 812ms/step - accuracy: 1.0000 - loss: 3.3891e-04 - val_accuracy: 0.3000 - val_loss: 3.5365
# Epoch 21/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 820ms/step - accuracy: 1.0000 - loss: 2.6812e-04 - val_accuracy: 0.3063 - val_loss: 7.4506
# Epoch 22/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 807ms/step - accuracy: 1.0000 - loss: 2.3596e-04 - val_accuracy: 0.3000 - val_loss: 13.2310
# Epoch 23/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 818ms/step - accuracy: 1.0000 - loss: 3.7658e-04 - val_accuracy: 0.3000 - val_loss: 16.8379
# Epoch 24/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 818ms/step - accuracy: 1.0000 - loss: 2.8639e-04 - val_accuracy: 0.3000 - val_loss: 19.0768
# Epoch 25/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 1.6086e-04 - val_accuracy: 0.3000 - val_loss: 19.9051
# Epoch 26/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 2.1690e-04 - val_accuracy: 0.3000 - val_loss: 20.2732
# Epoch 27/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 849ms/step - accuracy: 1.0000 - loss: 1.4121e-04 - val_accuracy: 0.3000 - val_loss: 19.4593
# Epoch 28/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 843ms/step - accuracy: 1.0000 - loss: 1.1101e-04 - val_accuracy: 0.3000 - val_loss: 17.8920
# Epoch 29/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 831ms/step - accuracy: 1.0000 - loss: 1.9965e-04 - val_accuracy: 0.3000 - val_loss: 15.6731
# Epoch 30/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 826ms/step - accuracy: 1.0000 - loss: 1.4785e-04 - val_accuracy: 0.3000 - val_loss: 13.2820
# Epoch 31/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 825ms/step - accuracy: 1.0000 - loss: 1.2991e-04 - val_accuracy: 0.3250 - val_loss: 10.0561
# Epoch 32/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 820ms/step - accuracy: 1.0000 - loss: 4.7393e-04 - val_accuracy: 0.3812 - val_loss: 7.1516
# Epoch 33/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 1.8653e-04 - val_accuracy: 0.5688 - val_loss: 4.8066
# Epoch 34/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 9.9179e-05 - val_accuracy: 0.7063 - val_loss: 3.3312
# Epoch 35/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 9.7300e-05 - val_accuracy: 0.7750 - val_loss: 2.4131
# Epoch 36/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 818ms/step - accuracy: 1.0000 - loss: 1.5161e-04 - val_accuracy: 0.8125 - val_loss: 1.7819
# Epoch 37/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 2.2118e-04 - val_accuracy: 0.8062 - val_loss: 1.5480
# Epoch 38/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 1.0097e-04 - val_accuracy: 0.8500 - val_loss: 1.2571
# Epoch 39/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 830ms/step - accuracy: 1.0000 - loss: 8.4339e-05 - val_accuracy: 0.8687 - val_loss: 1.0654
# Epoch 40/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 826ms/step - accuracy: 1.0000 - loss: 1.0492e-04 - val_accuracy: 0.8813 - val_loss: 0.9087
# Epoch 41/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 7.4740e-05 - val_accuracy: 0.8938 - val_loss: 0.7841
# Epoch 42/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 3.1315e-04 - val_accuracy: 0.8938 - val_loss: 0.6242
# Epoch 43/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 817ms/step - accuracy: 1.0000 - loss: 7.5769e-05 - val_accuracy: 0.8938 - val_loss: 0.6227
# Epoch 44/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 823ms/step - accuracy: 1.0000 - loss: 8.9209e-05 - val_accuracy: 0.8938 - val_loss: 0.6543
# Epoch 45/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 824ms/step - accuracy: 1.0000 - loss: 1.7870e-04 - val_accuracy: 0.9000 - val_loss: 0.6919
# Epoch 46/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 1.3267e-04 - val_accuracy: 0.9062 - val_loss: 0.6879
# Epoch 47/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 814ms/step - accuracy: 1.0000 - loss: 7.7894e-05 - val_accuracy: 0.8938 - val_loss: 0.6827
# Epoch 48/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 815ms/step - accuracy: 1.0000 - loss: 5.5417e-05 - val_accuracy: 0.8938 - val_loss: 0.6770
# Epoch 49/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 825ms/step - accuracy: 1.0000 - loss: 7.2875e-05 - val_accuracy: 0.9062 - val_loss: 0.6546
# Epoch 50/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 816ms/step - accuracy: 1.0000 - loss: 8.0230e-05 - val_accuracy: 0.9062 - val_loss: 0.7340
# Epoch 51/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 2.8814e-04 - val_accuracy: 0.9125 - val_loss: 0.6782
# Epoch 52/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 4.3600e-05 - val_accuracy: 0.9125 - val_loss: 0.6781
# Epoch 53/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 4.0854e-05 - val_accuracy: 0.9125 - val_loss: 0.6788
# Epoch 54/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 828ms/step - accuracy: 1.0000 - loss: 3.7215e-05 - val_accuracy: 0.9125 - val_loss: 0.6958
# Epoch 55/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 833ms/step - accuracy: 1.0000 - loss: 4.4206e-05 - val_accuracy: 0.9000 - val_loss: 0.7097
# Epoch 56/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 816ms/step - accuracy: 1.0000 - loss: 5.3770e-05 - val_accuracy: 0.9062 - val_loss: 0.7227
# Epoch 57/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 3.8426e-05 - val_accuracy: 0.9062 - val_loss: 0.7125
# Epoch 58/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 825ms/step - accuracy: 1.0000 - loss: 5.9407e-05 - val_accuracy: 0.8938 - val_loss: 0.7504
# Epoch 59/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 3.5676e-05 - val_accuracy: 0.8938 - val_loss: 0.7522
# Epoch 60/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 2.2024e-05 - val_accuracy: 0.8938 - val_loss: 0.7410
# Epoch 61/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 3.7534e-05 - val_accuracy: 0.8938 - val_loss: 0.7518
# Epoch 62/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 820ms/step - accuracy: 1.0000 - loss: 4.3268e-05 - val_accuracy: 0.8938 - val_loss: 0.7608
# Epoch 63/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 816ms/step - accuracy: 1.0000 - loss: 5.3309e-05 - val_accuracy: 0.9062 - val_loss: 0.7397
# Epoch 64/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 839ms/step - accuracy: 1.0000 - loss: 2.2449e-05 - val_accuracy: 0.9062 - val_loss: 0.7395
# Epoch 65/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 823ms/step - accuracy: 1.0000 - loss: 4.0557e-04 - val_accuracy: 0.9125 - val_loss: 0.7550
# Epoch 66/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 825ms/step - accuracy: 1.0000 - loss: 2.6632e-04 - val_accuracy: 0.8875 - val_loss: 1.2176
# Epoch 67/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 1.3471e-04 - val_accuracy: 0.8875 - val_loss: 1.1332
# Epoch 68/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 0.9391 - loss: 0.2815 - val_accuracy: 0.5125 - val_loss: 20.4344
# Epoch 69/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 824ms/step - accuracy: 0.8328 - loss: 0.4797 - val_accuracy: 0.3000 - val_loss: 6.3385
# Epoch 70/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 0.9406 - loss: 0.2274 - val_accuracy: 0.4375 - val_loss: 6.8850
# Epoch 71/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 825ms/step - accuracy: 0.9656 - loss: 0.1047 - val_accuracy: 0.7000 - val_loss: 1.7551
# Epoch 72/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 876ms/step - accuracy: 0.9875 - loss: 0.0380 - val_accuracy: 0.7750 - val_loss: 1.5592
# Epoch 73/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 880ms/step - accuracy: 0.9953 - loss: 0.0201 - val_accuracy: 0.5688 - val_loss: 1.9486
# Epoch 74/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 848ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9125 - val_loss: 0.4228
# Epoch 75/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 828ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8813 - val_loss: 0.4085
# Epoch 76/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 831ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8938 - val_loss: 0.4022
# Epoch 77/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 830ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8938 - val_loss: 0.4184
# Epoch 78/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 7.5847e-04 - val_accuracy: 0.8938 - val_loss: 0.4326
# Epoch 79/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 5.1210e-04 - val_accuracy: 0.8938 - val_loss: 0.4481
# Epoch 80/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 822ms/step - accuracy: 1.0000 - loss: 4.3935e-04 - val_accuracy: 0.8938 - val_loss: 0.4527
# Epoch 81/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 819ms/step - accuracy: 1.0000 - loss: 3.5227e-04 - val_accuracy: 0.9000 - val_loss: 0.4637
# Epoch 82/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 833ms/step - accuracy: 1.0000 - loss: 5.6378e-04 - val_accuracy: 0.9000 - val_loss: 0.4739
# Epoch 83/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 828ms/step - accuracy: 1.0000 - loss: 2.9023e-04 - val_accuracy: 0.9000 - val_loss: 0.4828
# Epoch 84/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 825ms/step - accuracy: 1.0000 - loss: 5.3291e-04 - val_accuracy: 0.9000 - val_loss: 0.4854
# Epoch 85/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 3.1687e-04 - val_accuracy: 0.9000 - val_loss: 0.4884
# Epoch 86/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 843ms/step - accuracy: 1.0000 - loss: 3.2725e-04 - val_accuracy: 0.9000 - val_loss: 0.5067
# Epoch 87/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 823ms/step - accuracy: 1.0000 - loss: 2.3747e-04 - val_accuracy: 0.8938 - val_loss: 0.5238
# Epoch 88/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 831ms/step - accuracy: 1.0000 - loss: 1.5194e-04 - val_accuracy: 0.8938 - val_loss: 0.5282
# Epoch 89/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 2.0962e-04 - val_accuracy: 0.8938 - val_loss: 0.5336
# Epoch 90/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 830ms/step - accuracy: 1.0000 - loss: 1.8973e-04 - val_accuracy: 0.9000 - val_loss: 0.5316
# Epoch 91/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 834ms/step - accuracy: 1.0000 - loss: 2.5314e-04 - val_accuracy: 0.8938 - val_loss: 0.5128
# Epoch 92/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 830ms/step - accuracy: 1.0000 - loss: 1.3951e-04 - val_accuracy: 0.8938 - val_loss: 0.5280
# Epoch 93/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 838ms/step - accuracy: 1.0000 - loss: 1.1440e-04 - val_accuracy: 0.8938 - val_loss: 0.5324
# Epoch 94/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 826ms/step - accuracy: 1.0000 - loss: 1.0775e-04 - val_accuracy: 0.8938 - val_loss: 0.5335
# Epoch 95/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 1.7804e-04 - val_accuracy: 0.8938 - val_loss: 0.5351
# Epoch 96/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 1.4644e-04 - val_accuracy: 0.8938 - val_loss: 0.5396
# Epoch 97/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 821ms/step - accuracy: 1.0000 - loss: 1.6885e-04 - val_accuracy: 0.8938 - val_loss: 0.5311
# Epoch 98/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 823ms/step - accuracy: 1.0000 - loss: 6.5265e-05 - val_accuracy: 0.8938 - val_loss: 0.5295
# Epoch 99/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 832ms/step - accuracy: 1.0000 - loss: 7.1843e-05 - val_accuracy: 0.8938 - val_loss: 0.5396
# Epoch 100/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 841ms/step - accuracy: 1.0000 - loss: 1.7663e-04 - val_accuracy: 0.8938 - val_loss: 0.5596
#
# Training complete!
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 328ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 648ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 328ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 342ms/step
#
# Classification Report (Source Validation):
#               precision    recall  f1-score   support
#
#          Dry       0.83      0.90      0.86        48
#       Medium       0.89      0.84      0.86        64
#          Wet       0.98      0.96      0.97        48
#
#     accuracy                           0.89       160
#    macro avg       0.90      0.90      0.90       160
# weighted avg       0.90      0.89      0.89       160
#
# Classification Report (Target Test):
#               precision    recall  f1-score   support
#
#          Dry       0.00      0.00      0.00        24
#       Medium       0.00      0.00      0.00        32
#          Wet       0.30      1.00      0.47        24
#
#     accuracy                           0.30        80
#    macro avg       0.10      0.33      0.16        80
# weighted avg       0.09      0.30      0.14        80
#
#
# METRICS SUMMARY
# ==================================================
# Metric               Source     Target
# --------------------------------------------------
# Accuracy              0.894      0.300
# Precision             0.896      0.091
# Recall                0.894      0.300
# F1                    0.894      0.140
# ==================================================
# C:\Users\rah350\.conda\envs\torch_blackwell\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\rah350\.conda\envs\torch_blackwell\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\rah350\.conda\envs\torch_blackwell\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\rah350\.conda\envs\torch_blackwell\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# All outputs saved to: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3

# %%
# ============================================================
# SOURCE ONLY BASELINE — ResNet50 (Visualization)
# Load saved outputs and generate confusion matrix,
# prediction grids, and copy original images.
# ============================================================

import os
import sys
import shutil
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

sys.path.append(r"D:\Woodchip_moisture_content\Dataset")
from dataset_2_3 import SourceDataset, WoodChipTargetEvalDataset

SAVE_DIR    = r"D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3"
LABEL_NAMES = ['Dry', 'Medium', 'Wet']

# ============================================================
# Load Saved Outputs
# ============================================================
Xs            = np.load(os.path.join(SAVE_DIR, "Xs.npy"))
ys_int        = np.load(os.path.join(SAVE_DIR, "ys_int.npy"))
Xt_eval       = np.load(os.path.join(SAVE_DIR, "Xt_eval.npy"))
yt_int        = np.load(os.path.join(SAVE_DIR, "yt_int.npy"))
ys_val_int    = np.load(os.path.join(SAVE_DIR, "ys_val_int.npy"))
val_preds     = np.load(os.path.join(SAVE_DIR, "val_preds.npy"))
src_probs_vis = np.load(os.path.join(SAVE_DIR, "src_probs_vis.npy"))
src_preds_vis = np.load(os.path.join(SAVE_DIR, "src_preds_vis.npy"))
tgt_probs_vis = np.load(os.path.join(SAVE_DIR, "tgt_probs_vis.npy"))
tgt_preds_vis = np.load(os.path.join(SAVE_DIR, "tgt_preds_vis.npy"))

print("Outputs loaded successfully.")

# ============================================================
# Load Original File Paths
# ============================================================
src_dataset = SourceDataset()
tgt_dataset = WoodChipTargetEvalDataset()

src_paths = [s[0] for s in src_dataset.samples]
tgt_paths = [s[0] for s in tgt_dataset.samples]

# ============================================================
# Confusion Matrix
# ============================================================
def plot_confusion_matrix(y_true, y_pred, title, filename):
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(6, 5), dpi=300)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=LABEL_NAMES, yticklabels=LABEL_NAMES,
                linewidths=0.5, ax=ax)
    ax.set_xlabel('Predicted Label', fontsize=12)
    ax.set_ylabel('True Label', fontsize=12)
    ax.set_title(title, fontsize=14, fontweight='bold')
    plt.tight_layout()
    save_path = os.path.join(SAVE_DIR, filename)
    plt.savefig(save_path, format='jpg', dpi=300, bbox_inches='tight')
    plt.show()
    print(f"Saved: {save_path}")

plot_confusion_matrix(yt_int, tgt_preds_vis,
                      'Confusion Matrix — Target Domain (Full)',
                      'confusion_matrix_target_full.jpg')

# ============================================================
# Visualization Grid
# ============================================================
np.random.seed(42)
src_indices = np.random.choice(len(Xs), 5, replace=False)
tgt_indices = np.random.choice(len(Xt_eval), 5, replace=False)

def save_visualization_grid(X, y_true, y_pred, y_probs, indices, title, filename):
    fig, axes = plt.subplots(1, 5, figsize=(15, 3), dpi=300)
    for ax, idx in zip(axes, indices):
        img = X[idx].copy()
        img = (img - img.min()) / (img.max() - img.min())
        ax.imshow(img)
        ax.axis('off')
        pred  = y_pred[idx]
        true  = y_true[idx]
        conf  = y_probs[idx][pred]
        color = 'green' if pred == true else 'red'
        ax.set_title(
            f"True: {LABEL_NAMES[true]}\nPred: {LABEL_NAMES[pred]}\nConf: {conf:.2f}",
            color=color, fontsize=10, fontweight='bold'
        )
    plt.suptitle(title, fontsize=14, fontweight='bold', y=1.05)
    plt.tight_layout()
    save_path = os.path.join(SAVE_DIR, filename)
    plt.savefig(save_path, format='jpg', dpi=300, bbox_inches='tight')
    plt.show()
    print(f"Saved: {save_path}")

print("\nVisualizing predictions on SOURCE domain samples:")
save_visualization_grid(Xs, ys_int, src_preds_vis, src_probs_vis, src_indices,
                        'ResNet50 Source Only Predictions (Source Domain)',
                        'source_predictions_grid.jpg')

print("\nVisualizing predictions on TARGET domain samples:")
save_visualization_grid(Xt_eval, yt_int, tgt_preds_vis, tgt_probs_vis, tgt_indices,
                        'ResNet50 Source Only Predictions (Target Domain)',
                        'target_predictions_grid.jpg')

# ============================================================
# Copy Original Images
# ============================================================
src_folder = os.path.join(SAVE_DIR, "source_samples")
tgt_folder = os.path.join(SAVE_DIR, "target_samples")
os.makedirs(src_folder, exist_ok=True)
os.makedirs(tgt_folder, exist_ok=True)

def copy_original_images(paths, y_true, y_pred, y_probs, indices, folder):
    for i, idx in enumerate(indices):
        true_label = LABEL_NAMES[y_true[idx]]
        pred_label = LABEL_NAMES[y_pred[idx]]
        conf       = y_probs[idx][y_pred[idx]]
        ext        = os.path.splitext(paths[idx])[1]
        filename   = f"{i+1}_True_{true_label}_Pred_{pred_label}_Conf_{conf:.2f}{ext}"
        save_path  = os.path.join(folder, filename)
        shutil.copy2(paths[idx], save_path)
        print(f"Saved: {save_path}")

print("\nCopying original source domain images...")
copy_original_images(src_paths, ys_int, src_preds_vis, src_probs_vis, src_indices, src_folder)

print("\nCopying original target domain images...")
copy_original_images(tgt_paths, yt_int, tgt_preds_vis, tgt_probs_vis, tgt_indices, tgt_folder)

print("\nDone! Check folders:")
print(f"  Source: {src_folder}")
print(f"  Target: {tgt_folder}")

# ============================================================
# Prediction Summary
# ============================================================
print("\n" + "="*60)
print("PREDICTION SUMMARY")
print("="*60)
src_n_correct = int(np.sum(src_preds_vis == ys_int))
tgt_n_correct = int(np.sum(tgt_preds_vis == yt_int))
print(f"Source Domain: {src_n_correct}/{len(ys_int)} correct ({accuracy_score(ys_int, src_preds_vis):.1%})")
print(f"Target Domain: {tgt_n_correct}/{len(yt_int)} correct ({accuracy_score(yt_int, tgt_preds_vis):.1%})")
print("="*60)
# Out:
# Outputs loaded successfully.
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\confusion_matrix_target_full.jpg
#
# Visualizing predictions on SOURCE domain samples:
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\source_predictions_grid.jpg
#
# Visualizing predictions on TARGET domain samples:
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\target_predictions_grid.jpg
#
# Copying original source domain images...
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\source_samples\1_True_Wet_Pred_Medium_Conf_0.62.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\source_samples\2_True_Medium_Pred_Medium_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\source_samples\3_True_Dry_Pred_Dry_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\source_samples\4_True_Medium_Pred_Medium_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\source_samples\5_True_Dry_Pred_Dry_Conf_1.00.jpg
#
# Copying original target domain images...
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\target_samples\1_True_Medium_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\target_samples\2_True_Medium_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\target_samples\3_True_Dry_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\target_samples\4_True_Dry_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\target_samples\5_True_Medium_Pred_Wet_Conf_1.00.jpg
#
# Done! Check folders:
#   Source: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\source_samples
#   Target: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_2_3\target_samples
#
# ============================================================
# PREDICTION SUMMARY
# ============================================================
# Source Domain: 783/800 correct (97.9%)
# Target Domain: 120/400 correct (30.0%)
# ============================================================
