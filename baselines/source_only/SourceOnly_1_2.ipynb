# %%
# ============================================================
# SOURCE ONLY BASELINE — ResNet50 (Training)
# Train only on source data, predict on target data.
# No domain adaptation. Used to judge how much DA methods help.
# ============================================================

import sys
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.utils import to_categorical
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt

sys.path.append(r"D:\Woodchip_moisture_content\Dataset")
from dataset_1_2 import SourceDataset, WoodChipTargetEvalDataset

# ============================================================
# 1. Settings
# ============================================================
SEED        = 42
NUM_CLASSES = 3
IMG_HEIGHT  = 224
IMG_WIDTH   = 224
CHANNELS    = 3
SAVE_DIR    = r"D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2"
os.makedirs(SAVE_DIR, exist_ok=True)

np.random.seed(SEED)
tf.random.set_seed(SEED)

# ============================================================
# 2. Load Data
# ============================================================
def dataset_to_numpy(dataset_1_2, has_labels=True):
    loader = DataLoader(dataset_1_2, batch_size=32, shuffle=False, num_workers=0)
    X_list, y_list = [], []
    for batch in loader:
        if has_labels:
            imgs, labels = batch
            y_list.append(labels.numpy())
        else:
            imgs = batch
        X_list.append(imgs.permute(0, 2, 3, 1).numpy())
    X = np.concatenate(X_list, axis=0).astype(np.float32)
    if has_labels:
        return X, np.concatenate(y_list, axis=0)
    return X

print("Loading data...")
Xs, ys_int      = dataset_to_numpy(SourceDataset())
Xt_eval, yt_int = dataset_to_numpy(WoodChipTargetEvalDataset())
print(f"Source: {Xs.shape} | Target: {Xt_eval.shape}")

# ============================================================
# 3. Train / Validation Split (source only)
# No target data used during training at all.
# ============================================================
ys = to_categorical(ys_int, num_classes=NUM_CLASSES)

Xs_train, Xs_val, ys_train, ys_val, ys_train_int, ys_val_int = train_test_split(
    Xs, ys, ys_int, test_size=0.2, random_state=SEED, stratify=ys_int
)

_, Xt_test, _, yt_test_int = train_test_split(
    Xt_eval, yt_int, test_size=0.2, random_state=SEED, stratify=yt_int
)

print(f"Xs_train: {Xs_train.shape} | Xs_val: {Xs_val.shape}")
print(f"Xt_test:  {Xt_test.shape}  (evaluation only)")

# ============================================================
# 4. Build ResNet50 Model
# ============================================================
def build_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, CHANNELS), num_classes=NUM_CLASSES):
    base = tf.keras.applications.ResNet50(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet'
    )
    base.trainable = True

    inputs = layers.Input(shape=input_shape)
    x = base(inputs, training=True)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return Model(inputs, outputs, name="resnet50_source_only")

model = build_model()
model.summary()

# ============================================================
# 5. Compile
# ============================================================
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ============================================================
# 6. Train on Source Only
# ============================================================
print("\nTraining Source Only model (ResNet50)...")
history = model.fit(
    Xs_train, ys_train,
    validation_data=(Xs_val, ys_val),
    epochs=100,
    batch_size=16,
    verbose=1
)
print("\nTraining complete!")

# ============================================================
# 7. Predictions
# ============================================================
val_preds     = np.argmax(model.predict(Xs_val), axis=1)
tgt_preds     = np.argmax(model.predict(Xt_test), axis=1)
src_probs_vis = model.predict(Xs)
src_preds_vis = np.argmax(src_probs_vis, axis=1)
tgt_probs_vis = model.predict(Xt_eval)
tgt_preds_vis = np.argmax(tgt_probs_vis, axis=1)

# ============================================================
# 8. Classification Reports
# ============================================================
print("\nClassification Report (Source Validation):")
print(classification_report(ys_val_int, val_preds, target_names=['Dry', 'Medium', 'Wet']))

print("Classification Report (Target Test):")
print(classification_report(yt_test_int, tgt_preds, target_names=['Dry', 'Medium', 'Wet']))

# ============================================================
# 9. Metrics Summary
# ============================================================
src_acc       = accuracy_score(ys_val_int, val_preds)
src_precision = precision_score(ys_val_int, val_preds, average='weighted')
src_recall    = recall_score(ys_val_int, val_preds, average='weighted')
src_f1        = f1_score(ys_val_int, val_preds, average='weighted')

tgt_acc       = accuracy_score(yt_test_int, tgt_preds)
tgt_precision = precision_score(yt_test_int, tgt_preds, average='weighted')
tgt_recall    = recall_score(yt_test_int, tgt_preds, average='weighted')
tgt_f1        = f1_score(yt_test_int, tgt_preds, average='weighted')

print("\nMETRICS SUMMARY")
print("=" * 50)
print(f"{'Metric':<16} {'Source':>10} {'Target':>10}")
print("-" * 50)
print(f"{'Accuracy':<16} {src_acc:>10.3f} {tgt_acc:>10.3f}")
print(f"{'Precision':<16} {src_precision:>10.3f} {tgt_precision:>10.3f}")
print(f"{'Recall':<16} {src_recall:>10.3f} {tgt_recall:>10.3f}")
print(f"{'F1':<16} {src_f1:>10.3f} {tgt_f1:>10.3f}")
print("=" * 50)

# ============================================================
# 10. Save Outputs
# ============================================================
np.save(os.path.join(SAVE_DIR, "Xs.npy"),            Xs)
np.save(os.path.join(SAVE_DIR, "ys_int.npy"),        ys_int)
np.save(os.path.join(SAVE_DIR, "Xt_eval.npy"),       Xt_eval)
np.save(os.path.join(SAVE_DIR, "yt_int.npy"),        yt_int)
np.save(os.path.join(SAVE_DIR, "ys_val_int.npy"),    ys_val_int)
np.save(os.path.join(SAVE_DIR, "val_preds.npy"),     val_preds)
np.save(os.path.join(SAVE_DIR, "yt_test_int.npy"),   yt_test_int)
np.save(os.path.join(SAVE_DIR, "tgt_preds.npy"),     tgt_preds)
np.save(os.path.join(SAVE_DIR, "src_probs_vis.npy"), src_probs_vis)
np.save(os.path.join(SAVE_DIR, "src_preds_vis.npy"), src_preds_vis)
np.save(os.path.join(SAVE_DIR, "tgt_probs_vis.npy"), tgt_probs_vis)
np.save(os.path.join(SAVE_DIR, "tgt_preds_vis.npy"), tgt_preds_vis)
print(f"\nAll outputs saved to: {SAVE_DIR}")
# Out:
# Loading data...
# Source: (800, 224, 224, 3) | Target: (800, 224, 224, 3)
# Xs_train: (640, 224, 224, 3) | Xs_val: (160, 224, 224, 3)
# Xt_test:  (160, 224, 224, 3)  (evaluation only)
# Model: "resnet50_source_only"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,145,539 (92.11 MB)
#  Trainable params: 24,092,419 (91.91 MB)
#  Non-trainable params: 53,120 (207.50 KB)
# Training Source Only model (ResNet50)...
# Epoch 1/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 50s 846ms/step - accuracy: 0.6797 - loss: 0.6649 - val_accuracy: 0.3000 - val_loss: 1.6153
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 832ms/step - accuracy: 0.9609 - loss: 0.1569 - val_accuracy: 0.3000 - val_loss: 4.0461
# Epoch 3/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 32s 810ms/step - accuracy: 0.9906 - loss: 0.0554 - val_accuracy: 0.3000 - val_loss: 13.5441
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 832ms/step - accuracy: 0.9922 - loss: 0.0355 - val_accuracy: 0.3000 - val_loss: 18.2966
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 827ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.2937 - val_loss: 24.9560
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 846ms/step - accuracy: 0.9984 - loss: 0.0105 - val_accuracy: 0.3000 - val_loss: 16.0698
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 834ms/step - accuracy: 0.9984 - loss: 0.0066 - val_accuracy: 0.3000 - val_loss: 21.0335
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 858ms/step - accuracy: 0.9984 - loss: 0.0092 - val_accuracy: 0.3000 - val_loss: 48.5498
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 836ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.3000 - val_loss: 27.5806
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 857ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.3000 - val_loss: 22.9296
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 829ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.3000 - val_loss: 21.5671
# Epoch 12/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 843ms/step - accuracy: 1.0000 - loss: 8.3295e-04 - val_accuracy: 0.3000 - val_loss: 19.6024
# Epoch 13/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 833ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3000 - val_loss: 19.0116
# Epoch 14/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 846ms/step - accuracy: 1.0000 - loss: 7.3965e-04 - val_accuracy: 0.3000 - val_loss: 17.8366
# Epoch 15/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 842ms/step - accuracy: 1.0000 - loss: 4.6643e-04 - val_accuracy: 0.3000 - val_loss: 15.9792
# Epoch 16/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 886ms/step - accuracy: 1.0000 - loss: 6.6268e-04 - val_accuracy: 0.3000 - val_loss: 14.7028
# Epoch 17/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 843ms/step - accuracy: 1.0000 - loss: 9.5506e-04 - val_accuracy: 0.3000 - val_loss: 11.7621
# Epoch 18/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 849ms/step - accuracy: 1.0000 - loss: 4.9723e-04 - val_accuracy: 0.3000 - val_loss: 10.6126
# Epoch 19/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 833ms/step - accuracy: 1.0000 - loss: 6.1589e-04 - val_accuracy: 0.3000 - val_loss: 7.7177
# Epoch 20/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 851ms/step - accuracy: 1.0000 - loss: 2.2510e-04 - val_accuracy: 0.4938 - val_loss: 5.6838
# Epoch 21/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 848ms/step - accuracy: 1.0000 - loss: 1.7056e-04 - val_accuracy: 0.5250 - val_loss: 4.1795
# Epoch 22/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 866ms/step - accuracy: 1.0000 - loss: 2.7154e-04 - val_accuracy: 0.4125 - val_loss: 3.2494
# Epoch 23/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 849ms/step - accuracy: 1.0000 - loss: 2.1207e-04 - val_accuracy: 0.3438 - val_loss: 2.4456
# Epoch 24/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 858ms/step - accuracy: 1.0000 - loss: 2.5919e-04 - val_accuracy: 0.2812 - val_loss: 2.0565
# Epoch 25/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 849ms/step - accuracy: 1.0000 - loss: 2.7065e-04 - val_accuracy: 0.4125 - val_loss: 2.3876
# Epoch 26/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 882ms/step - accuracy: 1.0000 - loss: 2.5706e-04 - val_accuracy: 0.4688 - val_loss: 3.3352
# Epoch 27/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 879ms/step - accuracy: 1.0000 - loss: 2.2883e-04 - val_accuracy: 0.4625 - val_loss: 3.9740
# Epoch 28/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 36s 896ms/step - accuracy: 1.0000 - loss: 2.1619e-04 - val_accuracy: 0.4812 - val_loss: 4.0656
# Epoch 29/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 869ms/step - accuracy: 1.0000 - loss: 7.1144e-04 - val_accuracy: 0.5063 - val_loss: 4.0194
# Epoch 30/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 865ms/step - accuracy: 1.0000 - loss: 2.1424e-04 - val_accuracy: 0.5125 - val_loss: 3.9783
# Epoch 31/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 870ms/step - accuracy: 1.0000 - loss: 2.2532e-04 - val_accuracy: 0.5500 - val_loss: 3.6580
# Epoch 32/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 854ms/step - accuracy: 1.0000 - loss: 1.2809e-04 - val_accuracy: 0.5813 - val_loss: 2.7239
# Epoch 33/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 863ms/step - accuracy: 1.0000 - loss: 1.1980e-04 - val_accuracy: 0.6812 - val_loss: 1.8218
# Epoch 34/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 863ms/step - accuracy: 1.0000 - loss: 1.0571e-04 - val_accuracy: 0.7812 - val_loss: 1.2399
# Epoch 35/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 849ms/step - accuracy: 1.0000 - loss: 2.1419e-04 - val_accuracy: 0.8562 - val_loss: 0.9435
# Epoch 36/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 843ms/step - accuracy: 1.0000 - loss: 4.8470e-05 - val_accuracy: 0.8813 - val_loss: 0.8044
# Epoch 37/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 835ms/step - accuracy: 1.0000 - loss: 4.0147e-05 - val_accuracy: 0.8938 - val_loss: 0.7315
# Epoch 38/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 841ms/step - accuracy: 1.0000 - loss: 9.1211e-05 - val_accuracy: 0.8938 - val_loss: 0.6916
# Epoch 39/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 838ms/step - accuracy: 1.0000 - loss: 9.3707e-05 - val_accuracy: 0.8750 - val_loss: 0.6851
# Epoch 40/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 854ms/step - accuracy: 1.0000 - loss: 1.1821e-04 - val_accuracy: 0.8813 - val_loss: 0.7048
# Epoch 41/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 845ms/step - accuracy: 1.0000 - loss: 1.2092e-04 - val_accuracy: 0.8875 - val_loss: 0.7399
# Epoch 42/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 872ms/step - accuracy: 1.0000 - loss: 5.6659e-05 - val_accuracy: 0.8875 - val_loss: 0.7491
# Epoch 43/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 863ms/step - accuracy: 1.0000 - loss: 5.5575e-05 - val_accuracy: 0.8875 - val_loss: 0.7453
# Epoch 44/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 856ms/step - accuracy: 1.0000 - loss: 6.6798e-05 - val_accuracy: 0.8875 - val_loss: 0.7516
# Epoch 45/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 846ms/step - accuracy: 1.0000 - loss: 8.9355e-05 - val_accuracy: 0.8750 - val_loss: 0.7476
# Epoch 46/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 855ms/step - accuracy: 1.0000 - loss: 4.6128e-05 - val_accuracy: 0.8750 - val_loss: 0.7521
# Epoch 47/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 843ms/step - accuracy: 1.0000 - loss: 4.2714e-05 - val_accuracy: 0.8750 - val_loss: 0.7576
# Epoch 48/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 841ms/step - accuracy: 1.0000 - loss: 1.0897e-04 - val_accuracy: 0.8750 - val_loss: 0.7543
# Epoch 49/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 838ms/step - accuracy: 1.0000 - loss: 5.0475e-05 - val_accuracy: 0.8750 - val_loss: 0.7576
# Epoch 50/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 850ms/step - accuracy: 1.0000 - loss: 6.8780e-05 - val_accuracy: 0.8750 - val_loss: 0.7719
# Epoch 51/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 850ms/step - accuracy: 1.0000 - loss: 2.6895e-05 - val_accuracy: 0.8687 - val_loss: 0.7820
# Epoch 52/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 844ms/step - accuracy: 1.0000 - loss: 5.0597e-05 - val_accuracy: 0.8750 - val_loss: 0.7885
# Epoch 53/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 836ms/step - accuracy: 1.0000 - loss: 3.5317e-05 - val_accuracy: 0.8750 - val_loss: 0.7950
# Epoch 54/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 844ms/step - accuracy: 1.0000 - loss: 9.4214e-05 - val_accuracy: 0.8687 - val_loss: 0.8098
# Epoch 55/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 839ms/step - accuracy: 1.0000 - loss: 3.3430e-05 - val_accuracy: 0.8687 - val_loss: 0.8066
# Epoch 56/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 850ms/step - accuracy: 1.0000 - loss: 7.1671e-05 - val_accuracy: 0.8687 - val_loss: 0.8061
# Epoch 57/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 834ms/step - accuracy: 1.0000 - loss: 4.1501e-05 - val_accuracy: 0.8687 - val_loss: 0.8074
# Epoch 58/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 846ms/step - accuracy: 1.0000 - loss: 3.0366e-05 - val_accuracy: 0.8687 - val_loss: 0.8095
# Epoch 59/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 845ms/step - accuracy: 1.0000 - loss: 2.0584e-05 - val_accuracy: 0.8687 - val_loss: 0.8041
# Epoch 60/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 860ms/step - accuracy: 1.0000 - loss: 2.5856e-05 - val_accuracy: 0.8687 - val_loss: 0.8114
# Epoch 61/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 837ms/step - accuracy: 1.0000 - loss: 5.4539e-05 - val_accuracy: 0.8687 - val_loss: 0.8235
# Epoch 62/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 863ms/step - accuracy: 1.0000 - loss: 3.1728e-05 - val_accuracy: 0.8687 - val_loss: 0.8389
# Epoch 63/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 36s 892ms/step - accuracy: 1.0000 - loss: 2.4543e-05 - val_accuracy: 0.8687 - val_loss: 0.8337
# Epoch 64/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 860ms/step - accuracy: 1.0000 - loss: 2.8696e-05 - val_accuracy: 0.8687 - val_loss: 0.8372
# Epoch 65/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 834ms/step - accuracy: 1.0000 - loss: 3.2335e-05 - val_accuracy: 0.8687 - val_loss: 0.8385
# Epoch 66/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 848ms/step - accuracy: 1.0000 - loss: 4.0351e-05 - val_accuracy: 0.8687 - val_loss: 0.8433
# Epoch 67/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 841ms/step - accuracy: 1.0000 - loss: 2.1062e-05 - val_accuracy: 0.8687 - val_loss: 0.8503
# Epoch 68/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 847ms/step - accuracy: 1.0000 - loss: 2.9130e-05 - val_accuracy: 0.8687 - val_loss: 0.8637
# Epoch 69/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 859ms/step - accuracy: 1.0000 - loss: 2.8643e-05 - val_accuracy: 0.8687 - val_loss: 0.8648
# Epoch 70/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 845ms/step - accuracy: 1.0000 - loss: 2.8983e-05 - val_accuracy: 0.8687 - val_loss: 0.8592
# Epoch 71/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 847ms/step - accuracy: 1.0000 - loss: 3.4493e-05 - val_accuracy: 0.8687 - val_loss: 0.8509
# Epoch 72/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 844ms/step - accuracy: 1.0000 - loss: 1.9391e-05 - val_accuracy: 0.8687 - val_loss: 0.8506
# Epoch 73/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 33s 835ms/step - accuracy: 1.0000 - loss: 2.4433e-05 - val_accuracy: 0.8687 - val_loss: 0.8573
# Epoch 74/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 850ms/step - accuracy: 1.0000 - loss: 2.5996e-05 - val_accuracy: 0.8750 - val_loss: 0.8468
# Epoch 75/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 861ms/step - accuracy: 1.0000 - loss: 2.5136e-05 - val_accuracy: 0.8750 - val_loss: 0.8530
# Epoch 76/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 852ms/step - accuracy: 1.0000 - loss: 1.3235e-05 - val_accuracy: 0.8750 - val_loss: 0.8540
# Epoch 77/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 859ms/step - accuracy: 1.0000 - loss: 2.2113e-05 - val_accuracy: 0.8750 - val_loss: 0.8503
# Epoch 78/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 854ms/step - accuracy: 1.0000 - loss: 1.7240e-05 - val_accuracy: 0.8750 - val_loss: 0.8550
# Epoch 79/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 841ms/step - accuracy: 1.0000 - loss: 1.4349e-05 - val_accuracy: 0.8750 - val_loss: 0.8733
# Epoch 80/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 858ms/step - accuracy: 1.0000 - loss: 1.5118e-05 - val_accuracy: 0.8750 - val_loss: 0.8573
# Epoch 81/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 843ms/step - accuracy: 1.0000 - loss: 1.7425e-05 - val_accuracy: 0.8750 - val_loss: 0.8631
# Epoch 82/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 852ms/step - accuracy: 1.0000 - loss: 1.5216e-05 - val_accuracy: 0.8750 - val_loss: 0.8689
# Epoch 83/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 844ms/step - accuracy: 1.0000 - loss: 1.4696e-05 - val_accuracy: 0.8750 - val_loss: 0.8752
# Epoch 84/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 856ms/step - accuracy: 1.0000 - loss: 1.3895e-05 - val_accuracy: 0.8750 - val_loss: 0.8761
# Epoch 85/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 843ms/step - accuracy: 1.0000 - loss: 1.2821e-05 - val_accuracy: 0.8750 - val_loss: 0.8862
# Epoch 86/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 856ms/step - accuracy: 1.0000 - loss: 2.6474e-05 - val_accuracy: 0.8750 - val_loss: 0.9071
# Epoch 87/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 883ms/step - accuracy: 1.0000 - loss: 1.2583e-05 - val_accuracy: 0.8750 - val_loss: 0.9222
# Epoch 88/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 863ms/step - accuracy: 1.0000 - loss: 1.6530e-05 - val_accuracy: 0.8750 - val_loss: 0.9133
# Epoch 89/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 849ms/step - accuracy: 1.0000 - loss: 1.2314e-05 - val_accuracy: 0.8750 - val_loss: 0.9089
# Epoch 90/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 850ms/step - accuracy: 1.0000 - loss: 1.9908e-05 - val_accuracy: 0.8750 - val_loss: 0.9192
# Epoch 91/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 843ms/step - accuracy: 1.0000 - loss: 1.0776e-05 - val_accuracy: 0.8750 - val_loss: 0.9225
# Epoch 92/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 871ms/step - accuracy: 1.0000 - loss: 2.0318e-05 - val_accuracy: 0.8687 - val_loss: 0.8806
# Epoch 93/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 36s 895ms/step - accuracy: 1.0000 - loss: 9.8023e-06 - val_accuracy: 0.8687 - val_loss: 0.8883
# Epoch 94/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 878ms/step - accuracy: 1.0000 - loss: 8.8642e-06 - val_accuracy: 0.8750 - val_loss: 0.8991
# Epoch 95/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 858ms/step - accuracy: 1.0000 - loss: 5.4082e-06 - val_accuracy: 0.8750 - val_loss: 0.9020
# Epoch 96/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 856ms/step - accuracy: 1.0000 - loss: 9.2781e-06 - val_accuracy: 0.8750 - val_loss: 0.9096
# Epoch 97/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 855ms/step - accuracy: 1.0000 - loss: 1.2522e-05 - val_accuracy: 0.8750 - val_loss: 0.9126
# Epoch 98/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 871ms/step - accuracy: 1.0000 - loss: 7.9245e-06 - val_accuracy: 0.8750 - val_loss: 0.9146
# Epoch 99/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 841ms/step - accuracy: 1.0000 - loss: 8.2850e-06 - val_accuracy: 0.8750 - val_loss: 0.9223
# Epoch 100/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 34s 852ms/step - accuracy: 1.0000 - loss: 1.0364e-05 - val_accuracy: 0.8750 - val_loss: 0.9265
#
# Training complete!
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 307ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 365ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 352ms/step
#
# Classification Report (Source Validation):
#               precision    recall  f1-score   support
#
#          Dry       0.78      0.90      0.83        48
#       Medium       0.91      0.77      0.83        64
#          Wet       0.94      1.00      0.97        48
#
#     accuracy                           0.88       160
#    macro avg       0.88      0.89      0.88       160
# weighted avg       0.88      0.88      0.87       160
#
# Classification Report (Target Test):
#               precision    recall  f1-score   support
#
#          Dry       0.45      0.92      0.60        48
#       Medium       0.50      0.12      0.20        64
#          Wet       0.78      0.75      0.77        48
#
#     accuracy                           0.55       160
#    macro avg       0.58      0.60      0.52       160
# weighted avg       0.57      0.55      0.49       160
#
#
# METRICS SUMMARY
# ==================================================
# Metric               Source     Target
# --------------------------------------------------
# Accuracy              0.875      0.550
# Precision             0.880      0.569
# Recall                0.875      0.550
# F1                    0.874      0.491
# ==================================================
#
# All outputs saved to: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2

# %%
# ============================================================
# SOURCE ONLY BASELINE — ResNet50 (Visualization)
# Load saved outputs and generate confusion matrix,
# prediction grids, and copy original images.
# ============================================================

import os
import sys
import shutil
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

sys.path.append(r"D:\Woodchip_moisture_content\Dataset")
from dataset_1_2 import SourceDataset, WoodChipTargetEvalDataset

SAVE_DIR    = r"D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2"
LABEL_NAMES = ['Dry', 'Medium', 'Wet']

# ============================================================
# Load Saved Outputs
# ============================================================
Xs            = np.load(os.path.join(SAVE_DIR, "Xs.npy"))
ys_int        = np.load(os.path.join(SAVE_DIR, "ys_int.npy"))
Xt_eval       = np.load(os.path.join(SAVE_DIR, "Xt_eval.npy"))
yt_int        = np.load(os.path.join(SAVE_DIR, "yt_int.npy"))
ys_val_int    = np.load(os.path.join(SAVE_DIR, "ys_val_int.npy"))
val_preds     = np.load(os.path.join(SAVE_DIR, "val_preds.npy"))
src_probs_vis = np.load(os.path.join(SAVE_DIR, "src_probs_vis.npy"))
src_preds_vis = np.load(os.path.join(SAVE_DIR, "src_preds_vis.npy"))
tgt_probs_vis = np.load(os.path.join(SAVE_DIR, "tgt_probs_vis.npy"))
tgt_preds_vis = np.load(os.path.join(SAVE_DIR, "tgt_preds_vis.npy"))

print("Outputs loaded successfully.")

# ============================================================
# Load Original File Paths
# ============================================================
src_dataset = SourceDataset()
tgt_dataset = WoodChipTargetEvalDataset()

src_paths = [s[0] for s in src_dataset.samples]
tgt_paths = [s[0] for s in tgt_dataset.samples]

# ============================================================
# Confusion Matrix
# ============================================================
def plot_confusion_matrix(y_true, y_pred, title, filename):
    cm = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(6, 5), dpi=300)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=LABEL_NAMES, yticklabels=LABEL_NAMES,
                linewidths=0.5, ax=ax)
    ax.set_xlabel('Predicted Label', fontsize=12)
    ax.set_ylabel('True Label', fontsize=12)
    ax.set_title(title, fontsize=14, fontweight='bold')
    plt.tight_layout()
    save_path = os.path.join(SAVE_DIR, filename)
    plt.savefig(save_path, format='jpg', dpi=300, bbox_inches='tight')
    plt.show()
    print(f"Saved: {save_path}")

plot_confusion_matrix(yt_int, tgt_preds_vis,
                      'Confusion Matrix — Target Domain (Full)',
                      'confusion_matrix_target_full.jpg')

# ============================================================
# Visualization Grid
# ============================================================
np.random.seed(42)
src_indices = np.random.choice(len(Xs), 5, replace=False)
tgt_indices = np.random.choice(len(Xt_eval), 5, replace=False)

def save_visualization_grid(X, y_true, y_pred, y_probs, indices, title, filename):
    fig, axes = plt.subplots(1, 5, figsize=(15, 3), dpi=300)
    for ax, idx in zip(axes, indices):
        img = X[idx].copy()
        img = (img - img.min()) / (img.max() - img.min())
        ax.imshow(img)
        ax.axis('off')
        pred  = y_pred[idx]
        true  = y_true[idx]
        conf  = y_probs[idx][pred]
        color = 'green' if pred == true else 'red'
        ax.set_title(
            f"True: {LABEL_NAMES[true]}\nPred: {LABEL_NAMES[pred]}\nConf: {conf:.2f}",
            color=color, fontsize=10, fontweight='bold'
        )
    plt.suptitle(title, fontsize=14, fontweight='bold', y=1.05)
    plt.tight_layout()
    save_path = os.path.join(SAVE_DIR, filename)
    plt.savefig(save_path, format='jpg', dpi=300, bbox_inches='tight')
    plt.show()
    print(f"Saved: {save_path}")

print("\nVisualizing predictions on SOURCE domain samples:")
save_visualization_grid(Xs, ys_int, src_preds_vis, src_probs_vis, src_indices,
                        'ResNet50 Source Only Predictions (Source Domain)',
                        'source_predictions_grid.jpg')

print("\nVisualizing predictions on TARGET domain samples:")
save_visualization_grid(Xt_eval, yt_int, tgt_preds_vis, tgt_probs_vis, tgt_indices,
                        'ResNet50 Source Only Predictions (Target Domain)',
                        'target_predictions_grid.jpg')

# ============================================================
# Copy Original Images
# ============================================================
src_folder = os.path.join(SAVE_DIR, "source_samples")
tgt_folder = os.path.join(SAVE_DIR, "target_samples")
os.makedirs(src_folder, exist_ok=True)
os.makedirs(tgt_folder, exist_ok=True)

def copy_original_images(paths, y_true, y_pred, y_probs, indices, folder):
    for i, idx in enumerate(indices):
        true_label = LABEL_NAMES[y_true[idx]]
        pred_label = LABEL_NAMES[y_pred[idx]]
        conf       = y_probs[idx][y_pred[idx]]
        ext        = os.path.splitext(paths[idx])[1]
        filename   = f"{i+1}_True_{true_label}_Pred_{pred_label}_Conf_{conf:.2f}{ext}"
        save_path  = os.path.join(folder, filename)
        shutil.copy2(paths[idx], save_path)
        print(f"Saved: {save_path}")

print("\nCopying original source domain images...")
copy_original_images(src_paths, ys_int, src_preds_vis, src_probs_vis, src_indices, src_folder)

print("\nCopying original target domain images...")
copy_original_images(tgt_paths, yt_int, tgt_preds_vis, tgt_probs_vis, tgt_indices, tgt_folder)

print("\nDone! Check folders:")
print(f"  Source: {src_folder}")
print(f"  Target: {tgt_folder}")

# ============================================================
# Prediction Summary
# ============================================================
print("\n" + "="*60)
print("PREDICTION SUMMARY")
print("="*60)
src_n_correct = int(np.sum(src_preds_vis == ys_int))
tgt_n_correct = int(np.sum(tgt_preds_vis == yt_int))
print(f"Source Domain: {src_n_correct}/{len(ys_int)} correct ({accuracy_score(ys_int, src_preds_vis):.1%})")
print(f"Target Domain: {tgt_n_correct}/{len(yt_int)} correct ({accuracy_score(yt_int, tgt_preds_vis):.1%})")
print("="*60)
# Out:
# Outputs loaded successfully.
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\confusion_matrix_target_full.jpg
#
# Visualizing predictions on SOURCE domain samples:
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\source_predictions_grid.jpg
#
# Visualizing predictions on TARGET domain samples:
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\target_predictions_grid.jpg
#
# Copying original source domain images...
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\source_samples\1_True_Wet_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\source_samples\2_True_Wet_Pred_Wet_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\source_samples\3_True_Dry_Pred_Dry_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\source_samples\4_True_Medium_Pred_Medium_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\source_samples\5_True_Dry_Pred_Dry_Conf_1.00.jpg
#
# Copying original target domain images...
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\target_samples\1_True_Medium_Pred_Dry_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\target_samples\2_True_Dry_Pred_Medium_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\target_samples\3_True_Medium_Pred_Dry_Conf_0.76.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\target_samples\4_True_Medium_Pred_Dry_Conf_1.00.jpg
# Saved: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\target_samples\5_True_Wet_Pred_Wet_Conf_1.00.jpg
#
# Done! Check folders:
#   Source: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\source_samples
#   Target: D:\Woodchip_moisture_content\Adapt_codes\SourceOnly\SourceOnly_1_2\target_samples
#
# ============================================================
# PREDICTION SUMMARY
# ============================================================
# Source Domain: 780/800 correct (97.5%)
# Target Domain: 456/800 correct (57.0%)
# ============================================================
